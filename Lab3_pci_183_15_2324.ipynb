# %% [markdown]
# <a href="https://colab.research.google.com/github/Suhrid-Khan/AI-lab-work/blob/master/Lab3_pci_183_15_2324.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sub=[]

def separator():
  print('#####################')

def gaph():
  print("-----------------------")

def menu():
  separator()
  print("Menu List")
  separator()
  print("<1> View all Courses")
  print("<2> Add Courses")
  print("<3> Delect Courses")
  print("<4> Remove All Courses")
  print("<5> EXIT")
  print("Enter Your selected key")
  operation_code = int(input(">>"))
  gaph()

  try:
    #view courses
    if operation_code == 1:
      count=len(sub)
      if count == 0 :
        print("No Courses Add...Plz Add Courses")
      else:
        for i in range(count):
          print(f"{i}> {sub[i]}")
      menu()
      
    #Add Courses
    elif operation_code == 2:
      add_courses()
  
    #Delect Courses
    elif operation_code == 3:
      print("<1> Delect By Index number")
      print("<2> Delect By courses name")
      del_itm = int(input("Enter your selection >> "))
      if del_itm == 1:
        del_vlu = int(input("Enter Index Number >> "))
        del sub[del_vlu]
        print("Mark As Done")
        menu()
      elif del_itm == 2:
        del_vlu = input("Enter Courses Name >> ")
        sub.remove(del_vlu)
        print("Mark As Done")
        menu()
      else:
        print("Enter A valid Input")
        menu()
    
    #remove All
    elif operation_code == 4:
      sub.clear()
      menu()
    #exit from here
    else:
      print("GOOD BYE")
      

  except:
    print("********Operation Error!*********")
    menu()


def add_courses():
  add_item = input("Type your Courses name for adding>> ").upper()
  sub.append(add_item)
  print(sub)
  add_num = input("Do You want To Add More Then Type (y) Otherwise Type (n)>> ")
  if add_num == 'y':
    add_courses()
  elif add_num == 'n':
    menu()
  else:
    print("Enter Valid Value")
    add_courses()

menu()
# Out:
# #####################
# Menu List
# #####################
# <1> View all Courses
# <2> Add Courses
# <3> Delect Courses
# <4> Remove All Courses
# <5> EXIT
# Enter Your selected key
# >>2
# -----------------------
# Type your Courses name for adding>> cse111
# ['CSE111']
# Do You want To Add More Then Type (y) Otherwise Type (n)>> y
# Type your Courses name for adding>> cse112
# ['CSE111', 'CSE112']
# Do You want To Add More Then Type (y) Otherwise Type (n)>> y
# Type your Courses name for adding>> cse113
# ['CSE111', 'CSE112', 'CSE113']
# Do You want To Add More Then Type (y) Otherwise Type (n)>> y
# Type your Courses name for adding>> cse114
# ['CSE111', 'CSE112', 'CSE113', 'CSE114']
# Do You want To Add More Then Type (y) Otherwise Type (n)>> y
# Type your Courses name for adding>> cse115
# ['CSE111', 'CSE112', 'CSE113', 'CSE114', 'CSE115']
# Do You want To Add More Then Type (y) Otherwise Type (n)>> y
# Type your Courses name for adding>> cse116
# ...
